# %% [markdown]
# Taking a fresh look at the PyData stack according to [this guide](http://twiecki.github.io/blog/2014/11/18/python-for-data-science/)

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('wxVx54ax47s')

# %%
import pandas as pd

# %%
df = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20170226'),
                    'C' : pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D' : pd.Series([1, 2, 1, 2], dtype='int32'),
                    'E' : pd.Categorical(['test', 'train', 'test', 'train']),
                    'F' : 'foo'})

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2017-02-26  1.0  1   test  foo
# 1  1.0 2017-02-26  1.0  2  train  foo
# 2  1.0 2017-02-26  1.0  1   test  foo
# 3  1.0 2017-02-26  1.0  2  train  foo

# %%
df.B
# Out:
# 0   2017-02-26
# 1   2017-02-26
# 2   2017-02-26
# 3   2017-02-26
# Name: B, dtype: datetime64[ns]

# %%
df.groupby('E').sum().D
# Out:
# E
# test     2
# train    4
# Name: D, dtype: int32

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
sns.jointplot("total_bill", 'tip', tips, kind='reg');

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill', 'tip', tips, col='smoker');
